# %% [markdown]
# # Getting Financial Data - Google Finance

# %% [markdown]
# ### Introduction:
#
# This time you will get data from a website.
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# package to extract data from various Internet sources into a DataFrame
# make sure you have it installed
from pandas_datareader import data, wb

# package for dates
import datetime as dt

# %% [markdown]
# ### Step 2. Create your time range (start and end variables). The start date should be 01/01/2015 and the end date should be 12/31/2016.

# %%
start = dt.datetime(2015, 1, 1)

end = dt.datetime(2016, 12, 31)


print(start)
print(end)
# Out:
# 2015-01-01 00:00:00
# 2016-12-31 00:00:00

# %% [markdown]
# ### Step 3. Select the Apple, Tesla, Twitter, IBM, LinkedIn stocks symbols and assign them to a variable called stocks

# %%
stocks = ['AAPL', 'TSLA', 'IBM']

# %% [markdown]
# ### Step 4. Read the data from yahoo, assign to df and print it

# %%
df = data.DataReader(stocks, 'yahoo', start, end)
df
# Out:
# Attributes  Adj Close                             Close             \
# Symbols          AAPL       TSLA         IBM       AAPL       TSLA
# Date
# 2015-01-02  24.714512  43.862000  113.538864  27.332500  43.862000
# 2015-01-05  24.018263  42.018002  111.752327  26.562500  42.018002
# 2015-01-06  24.020525  42.256001  109.342278  26.565001  42.256001
# 2015-01-07  24.357344  42.189999  108.627701  26.937500  42.189999
# 2015-01-08  25.293209  42.124001  110.988747  27.972500  42.124001
# ...               ...        ...         ...        ...        ...
# 2016-12-23  27.384647  42.667999  125.206581  29.129999  42.667999
# 2016-12-27  27.558561  43.905998  125.529541  29.315001  43.905998
# 2016-12-28  27.441061  43.948002  124.816109  29.190001  43.948002
# 2016-12-29  27.434004  42.936001  125.124016  29.182501  42.936001
# 2016-12-30  27.220137  42.737999  124.665863  28.955000  42.737999
#
# Attributes                   High                               Low  \
# ...

# %% [markdown]
# ### Step 5.  What is the type of structure of df ?

# %%
# 'multi-index pandas.core.frame.DataFrame'

# %% [markdown]
# ### Step 6. Print all the Items axis values
# #### To learn more about the Multi-index structure go to the [documentation](https://pandas.pydata.org/pandas-docs/stable/user_guide/advanced.html)

# %%
df.columns.levels[0]
# Out:
# Index(['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object', name='Attributes')

# %% [markdown]
# ### Step 7. Good, now we know  the data avaiable. Create a dataFrame called vol, with the Volume values.

# %%
vol = df['Volume']
vol.head()
# Out:
# Symbols            AAPL        TSLA        IBM
# Date
# 2015-01-02  212818400.0  23822000.0  5779673.0
# 2015-01-05  257142000.0  26842500.0  5104898.0
# 2015-01-06  263188400.0  31309500.0  6429448.0
# 2015-01-07  160423600.0  14842000.0  4918083.0
# 2015-01-08  237458000.0  17212500.0  4431693.0

# %% [markdown]
# ### Step 8. Aggregate the data of Volume to weekly
# #### Hint: Be careful to not sum data from the same week of 2015 and other years.

# %%
vol['week'] = vol.index.isocalendar().week
vol['year'] = vol.index.isocalendar().year

week = vol.groupby(['week','year']).sum()
week.head()
# Out:
# C:\Users\vrive\AppData\Local\Temp/ipykernel_16892/3918028954.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vol['week'] = vol.index.isocalendar().week
# C:\Users\vrive\AppData\Local\Temp/ipykernel_16892/3918028954.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vol['year'] = vol.index.isocalendar().year
# Symbols            AAPL         TSLA         IBM
# week year
# 1    2015  2.128184e+08   23822000.0   5779673.0
#      2016  1.375161e+09  104877000.0  26415265.0
# ...

# %% [markdown]
# ### Step 9. Find all the volume traded in the year of 2015

# %%
del vol['week']
vol['year'] = vol.index.isocalendar().year

year = vol.groupby(['year']).sum()
year
# Out:
# C:\Users\vrive\AppData\Local\Temp/ipykernel_16892/4007670500.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vol['year'] = vol.index.isocalendar().year
# Symbols          AAPL          TSLA           IBM
# year
# 2015     5.226420e+10  5.441089e+09  1.156439e+09
# 2016     3.872991e+10  5.811808e+09  1.065462e+09

# %% [markdown]
# ### BONUS: Create your own question and answer it.
